# %% [markdown]
# # Bienvenido al comienzo de tu aventura en Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">¿Listo para la acción?</h2>
# <span style="color:#ff7800;">¿Has completado todos los pasos de configuración en la carpeta <a href="../setup/">setup</a>?<br/>
#
# ¿Has consultado las guías en la carpeta <a href="../guides/01_intro.ipynb">guides</a>?<br/>
#
# En ese caso, ¡estás listo! </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#00bfff;">Este código es un recurso activo; esté atento a mis actualizaciones</h2>
# <span style="color:#00bfff;">Actualizo periódicamente. A medida que los usuarios hacen preguntas o tienen problemas, añado más ejemplos y mejoro las explicaciones. Por lo tanto, es posible que el código a continuación no sea idéntico al de los vídeos, ya que he añadido más pasos y mejores comentarios. Considérelo como un libro interactivo que acompaña a las clases.<br/><br/>
# Intento enviar correos electrónicos regularmente con actualizaciones importantes relacionadas con el curso. Puedes encontrarlo en la sección "Anuncios" de Udemy, en la barra lateral izquierda. También puedes optar por recibir mis correos electrónicos a través de la configuración de notificaciones en Udemy. Soy respetuoso con tu bandeja de entrada y siempre intento aportar valor con mis correos.
#
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# ### Y por favor, recuerda contactarme si puedo ayudarte.
#
# Me encantaría conectar contigo: https://www.linkedin.com/in/juan-gabriel-gomila-salas/
#
# ### ¿Eres nuevo en Notebooks como este? ¡Visita la carpeta de guías!
#
# Para comprobar que ya has añadido las extensiones de Python y Jupyter a Cursor, si aún no las tienes instaladas:
# - Abre Extensiones (Ver >> Extensiones).
# - Busca Python y, cuando aparezcan los resultados, haz clic en la de ms-python e instálala si aún no está instalada.
# - Busca Jupyter y, cuando aparezcan los resultados, haz clic en la de Microsoft e instálala si aún no está instalada.
# Luego, ve a Ver >> Explorador para volver al Explorador de archivos.
#
# Y luego:
# 1. Haz clic donde dice "Seleccionar Kernel" cerca de la esquina superior derecha y selecciona la opción `.venv (Python 3.12.9)` o similar, que debería ser la primera opción o la más destacada. Quizás primero debas seleccionar "Entornos de Python".
# 2. Haz clic en cada celda a continuación, comenzando por la celda inmediatamente inferior a este texto, y presiona Mayús+Intro para ejecutar.
# 3. ¡Disfruta!
#
# Después de hacer clic en "Seleccionar Kernel", si no hay ninguna opción como `.venv (Python 3.12.9)`, haz lo siguiente:
# 1. En Mac: En el menú Cursor, selecciona Configuración >> Configuración de VS Code (NOTA: asegúrate de seleccionar `Configuración de VSCode`, no `Configuración de Cursor`). En una PC con Windows: En el menú Archivo, seleccione Preferencias >> Configuración de VS Code (NOTA: asegúrate de seleccionar "Configuración de VS Code" y no "Configuración de Cursor").
# 2. En la barra de búsqueda de Configuración, escriba "venv".
# 3. En el campo "Ruta a la carpeta con la lista de entornos virtuales", introduzca la ruta a la raíz del proyecto, como C:\Users\username\projects\agents (en una PC con Windows) o /Users/username/projects/agents (en Mac o Linux).
# Inténtelo de nuevo.
#
# ¿Tiene problemas porque faltan versiones de Python en la lista? ¿Ha usado Anaconda anteriormente? Podría estar interfiriendo. Salga de Cursor, abra una nueva línea de comandos y asegúrese de que su entorno de Anaconda esté desactivado: `conda deactivate`
# Si aún tiene problemas con las versiones de Conda y Python, es posible que también deba ejecutar esto: `conda config --set auto_activate_base false`
# Y luego, desde el directorio Agentes, debería poder ejecutar `uv python list` y ver la versión de Python 3.12.

# %%
# Empecemos por hacer un import
from dotenv import load_dotenv

# %%
# A continuación, es el momento de cargar las claves API en las variables de entorno.

load_dotenv(override=True)
# Out:
# True

# %%
# Comprobamos las claves

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"La clave API de OpenAI existe y empieza por {openai_api_key[:8]}")
else:
    print("La clave API de OpenAI no existe - Dirígete a la guía de solución de problemas en la carpeta de configuración.")
# Out:
# La clave API de OpenAI existe y empieza por sk-proj-

# %%
# Y ahora, la importante declaración de importación
# Si recibes un error de importación, consulta la guía de solución de problemas

from openai import OpenAI

# %%
# Ahora crearemos una instancia de la clase OpenAI.
# Si no estás seguro de lo que significa crear una instancia de una clase, ¡visita la carpeta de guías!
# Si recibes un error de nombre, visita la carpeta de guías para obtener más información sobre los errores de nombre.

openai = OpenAI()

# %%
# Crea una lista de mensajes en el formato familiar de OpenAI

messages = [{"role": "user", "content": "¿Cuanto es 2+2?"}]

# %%
# ¡Y ahora, a llamarlo! Si tienes algún problema, consulta la guía de solución de problemas.
# Usa GPT 4.1 nano, el modelo increíblemente económico.

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 es igual a 4.

# %%
# Y ahora, vamos a llamar a la API de OpenAI

question = "Proponga una pregunta difícil y desafiante para evaluar el coeficiente intelectual de alguien. Responde únicamente con la pregunta."
messages = [{"role": "user", "content": question}]

# %%
# Pregúntale: usa GPT 4.1 mini, aún barato pero más potente que nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Si en un reloj analógico las manecillas forman un ángulo de 90 grados a las 3:15, ¿a qué otra(s) hora(s) entre las 3:00 y las 4:00 las manecillas volverán a formar ese mismo ángulo? Explica tu razonamiento.

# %%
# una nueva lista de mensajes
messages = [{"role": "user", "content": question}]

# %%
# Hacemos una nueva pregunta

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Vamos a analizar el problema paso a paso.
#
# ---
#
# ### Planteamiento
#
# - El reloj analógico tiene una **manecilla de las horas** y una **manecilla de los minutos**.
# - Se nos dice que a las **3:15** las manecillas forman un ángulo de 90 grados.
# - La pregunta es: **¿a qué otra(s) hora(s), entre las 3:00 y las 4:00, las manecillas volverán a formar ese mismo ángulo (90°)?**
#
# ---
#
# ### Paso 1: Calcular el ángulo entre las manecillas a una hora cualquiera entre las 3:00 y las 4:00
#
# Para un reloj analógico,
#
# - La **manecilla de las horas** avanza 0.5° por minuto (360° / 12 horas / 60 minutos):
#
#   \[
#   \text{Angulo horas} = 30 \times H + 0.5 \times M
#   \]
#
#   (donde \(H\) es la hora y \(M\) los minutos)
#
# - La **manecilla de los minutos** avanza 6° por minuto (360° / 60 minutos):
#
#   \[
#   \text{Angulo minutos} = 6 \times M
#   \]
#
# Entonces, el **ángulo entre manecillas** será:
#
# \[
# \theta = |\text{Angulo horas} - \text{Angulo minutos}|
# \]
#
# Pero como el ángulo entre manecillas debe ser siempre el menor ángulo, tomamos el mínimo entre \(\theta\) y \(360° - \theta\):
#
# \[
# \text{Ángulo entre manecillas} = \min(\theta, 360° - \theta)
# \]
#
# ---
#
# ### Paso 2: Confirmar el ángulo a las 3:15
#
# Calculemos el ángulo entre las manecillas a las 3:15,
#
# - \(H = 3\), \(M = 15\)
# - Ángulo horas:
#
# \[
# 30 \times 3 + 0.5 \times 15 = 90 + 7.5 = 97.5^\circ
# \]
#
# - Ángulo minutos:
#
# \[
# 6 \times 15 = 90^\circ
# \]
#
# - Diferencia:
#
# \[
# |97.5 - 90| = 7.5^\circ
# \]
#
# El ángulo más pequeño es:
#
# \[
# \min(7.5^\circ, 360 - 7.5^\circ) = 7.5^\circ
# \]
#
# **Observamos que a las 3:15 el ángulo no es 90°, sino 7.5°.**
#
# ---
#
# ### Paso 3: Replantear
#
# El problema establece que a las 3:15 las manecillas forman un ángulo de 90°, pero nuestro cálculo muestra que no es así.
#
# Veamos si el enunciado quiere decir que hay un momento *cercano* a las 3:15 en que las manecillas forman 90°.
#
# Volvamos a escribir la expresión para encontrar todos los minutos \(M\) entre 0 y 60 (entre 3:00 y 4:00) donde el ángulo sea 90°.
#
# Usamos que la diferencia entre ángulos es:
#
# \[
# |30 \times 3 + 0.5 M - 6 M| = 90 \quad \text{o} \quad 360 - |30 \times 3 + 0.5 M - 6 M| = 90
# \]
#
# El primer caso:
#
# \[
# |90 + 0.5 M - 6 M| = 90
# \]
#
# O sea,
#
# \[
# |90 - 5.5 M| = 90
# \]
#
# Esta ecuación se separa en dos casos:
#
# 1. \(90 - 5.5 M = 90 \implies -5.5 M = 0 \implies M=0\)
# 2. \(90 - 5.5 M = -90 \implies -5.5 M = -180 \implies M = \frac{180}{5.5} = 32.7272...\)
#
# ---
#
# ### Paso 4: Comprobar el segundo caso de la diferencia
#
# El segundo caso para el ángulo mínimo:
#
# \[
# 360 - |90 - 5.5 M| = 90
# \]
# \[
# |90 - 5.5 M| = 270
# \]
#
# Pero el valor absoluto es máximo 360, y para valores \(M\) entre 0 y 60, calculemos si hay solución:
#
# \[
# |90 - 5.5 M| = 270
# \]
#
# Esto se resuelve en:
#
# - \(90 - 5.5 M = 270 \to -5.5 M = 180 \to M = -\frac{180}{5.5} = -32.7272...\) (no válido porque minutos no son negativos)
# - \(90 - 5.5 M = -270 \to -5.5 M = -360 \to M = \frac{360}{5.5} = 65.4545...\) (fuera del rango 0-60)
#
# Por lo tanto, este caso no aporta soluciones válidas.
#
# ---
#
# ### Paso 5: Horas en que las manecillas forman 90 grados entre las 3:00 y las 4:00
#
# Las soluciones válidas para \(M\) son:
#
# - \(M = 0\) minutos → a las **3:00**
# - \(M \approx 32.7272\) minutos → a las **3:32:44** (aproximadamente)
#
# Por lo tanto, las manecillas forman un ángulo de 90 grados a las **3:00** y también aproximadamente a las **3:32:44**.
#
# ---
#
# ### Paso 6: Verificación práctica
#
# - A las 3:00
#
# \[
# \text{Ángulo horas} = 30 \times 3 + 0.5 \times 0 = 90^\circ
# \]
# \[
# \text{Ángulo minutos} = 6 \times 0=0^\circ
# \]
# Diferencia:
#
# \[
# |90 - 0| = 90^\circ
# \]
#
# Ángulo menor es 90°, correcto.
#
# - A las 3:32:44 (aprox 32.7272 minutos)
#
# \[
# \text{Ángulo horas} = 90 + 0.5 \times 32.7272 = 90 + 16.3636 = 106.3636^\circ
# \]
# \[
# \text{Ángulo minutos} = 6 \times 32.7272 = 196.3636^\circ
# \]
# Diferencia:
#
# \[
# |106.3636 - 196.3636| = 90^\circ
# \]
#
# Lo que confirma el resultado.
#
# ---
#
# ### **Conclusión final**
#
# Aunque a las 3:15 las manecillas no forman un ángulo de 90°, entre las 3:00 y las 4:00 las manecillas forman un ángulo de 90°:
#
# - A las **3:00**.
# - Aproximadamente a las **3:32:44**.
#
# ---
#
# Si el problema se refería a que a las 3:15 se había visto un ángulo de 90° y luego queremos saber cuándo se repite, entonces las respuestas son:
#
# \[
# \boxed{
# \text{Sólo aproximadamente a las 3:32:44 minutos}
# }
# \]
#
# Pero como a las 3:15 el ángulo no es 90 grados, quizás el problema tiene algún error o está preguntando en general.
#
# ---
#
# **¿Quieres que te ayude a calcular exactamente en qué minutos las manecillas forman un ángulo de 90° en el intervalo dado?**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Vamos a analizar el problema paso a paso.
#
# ---
#
# ### Planteamiento
#
# - El reloj analógico tiene una **manecilla de las horas** y una **manecilla de los minutos**.
# - Se nos dice que a las **3:15** las manecillas forman un ángulo de 90 grados.
# - La pregunta es: **¿a qué otra(s) hora(s), entre las 3:00 y las 4:00, las manecillas volverán a formar ese mismo ángulo (90°)?**
#
# ---
#
# ### Paso 1: Calcular el ángulo entre las manecillas a una hora cualquiera entre las 3:00 y las 4:00
#
# Para un reloj analógico,
#
# - La **manecilla de las horas** avanza 0.5° por minuto (360° / 12 horas / 60 minutos):
#
#   \[
#   \text{Angulo horas} = 30 \times H + 0.5 \times M
#   \]
#
#   (donde \(H\) es la hora y \(M\) los minutos)
#
# - La **manecilla de los minutos** avanza 6° por minuto (360° / 60 minutos):
#
#   \[
#   \text{Angulo minutos} = 6 \times M
#   \]
#
# Entonces, el **ángulo entre manecillas** será:
#
# \[
# \theta = |\text{Angulo horas} - \text{Angulo minutos}|
# \]
#
# Pero como el ángulo entre manecillas debe ser siempre el menor ángulo, tomamos el mínimo entre \(\theta\) y \(360° - \theta\):
#
# \[
# \text{Ángulo entre manecillas} = \min(\theta, 360° - \theta)
# \]
#
# ---
#
# ### Paso 2: Confirmar el ángulo a las 3:15
#
# Calculemos el ángulo entre las manecillas a las 3:15,
#
# - \(H = 3\), \(M = 15\)
# - Ángulo horas:
#
# \[
# 30 \times 3 + 0.5 \times 15 = 90 + 7.5 = 97.5^\circ
# \]
#
# - Ángulo minutos:
#
# \[
# 6 \times 15 = 90^\circ
# \]
#
# - Diferencia:
#
# \[
# |97.5 - 90| = 7.5^\circ
# \]
#
# El ángulo más pequeño es:
#
# \[
# \min(7.5^\circ, 360 - 7.5^\circ) = 7.5^\circ
# \]
#
# **Observamos que a las 3:15 el ángulo no es 90°, sino 7.5°.**
#
# ---
#
# ### Paso 3: Replantear
#
# El problema establece que a las 3:15 las manecillas forman un ángulo de 90°, pero nuestro cálculo muestra que no es así.
#
# Veamos si el enunciado quiere decir que hay un momento *cercano* a las 3:15 en que las manecillas forman 90°.
#
# Volvamos a escribir la expresión para encontrar todos los minutos \(M\) entre 0 y 60 (entre 3:00 y 4:00) donde el ángulo sea 90°.
#
# Usamos que la diferencia entre ángulos es:
#
# \[
# |30 \times 3 + 0.5 M - 6 M| = 90 \quad \text{o} \quad 360 - |30 \times 3 + 0.5 M - 6 M| = 90
# \]
#
# El primer caso:
#
# \[
# |90 + 0.5 M - 6 M| = 90
# \]
#
# O sea,
#
# \[
# |90 - 5.5 M| = 90
# \]
#
# Esta ecuación se separa en dos casos:
#
# 1. \(90 - 5.5 M = 90 \implies -5.5 M = 0 \implies M=0\)
# 2. \(90 - 5.5 M = -90 \implies -5.5 M = -180 \implies M = \frac{180}{5.5} = 32.7272...\)
#
# ---
#
# ### Paso 4: Comprobar el segundo caso de la diferencia
#
# El segundo caso para el ángulo mínimo:
#
# \[
# 360 - |90 - 5.5 M| = 90
# \]
# \[
# |90 - 5.5 M| = 270
# \]
#
# Pero el valor absoluto es máximo 360, y para valores \(M\) entre 0 y 60, calculemos si hay solución:
#
# \[
# |90 - 5.5 M| = 270
# \]
#
# Esto se resuelve en:
#
# - \(90 - 5.5 M = 270 \to -5.5 M = 180 \to M = -\frac{180}{5.5} = -32.7272...\) (no válido porque minutos no son negativos)
# - \(90 - 5.5 M = -270 \to -5.5 M = -360 \to M = \frac{360}{5.5} = 65.4545...\) (fuera del rango 0-60)
#
# Por lo tanto, este caso no aporta soluciones válidas.
#
# ---
#
# ### Paso 5: Horas en que las manecillas forman 90 grados entre las 3:00 y las 4:00
#
# Las soluciones válidas para \(M\) son:
#
# - \(M = 0\) minutos → a las **3:00**
# - \(M \approx 32.7272\) minutos → a las **3:32:44** (aproximadamente)
#
# Por lo tanto, las manecillas forman un ángulo de 90 grados a las **3:00** y también aproximadamente a las **3:32:44**.
#
# ---
#
# ### Paso 6: Verificación práctica
#
# - A las 3:00
#
# \[
# \text{Ángulo horas} = 30 \times 3 + 0.5 \times 0 = 90^\circ
# \]
# \[
# \text{Ángulo minutos} = 6 \times 0=0^\circ
# \]
# Diferencia:
#
# \[
# |90 - 0| = 90^\circ
# \]
#
# Ángulo menor es 90°, correcto.
#
# - A las 3:32:44 (aprox 32.7272 minutos)
#
# \[
# \text{Ángulo horas} = 90 + 0.5 \times 32.7272 = 90 + 16.3636 = 106.3636^\circ
# \]
# \[
# \text{Ángulo minutos} = 6 \times 32.7272 = 196.3636^\circ
# \]
# Diferencia:
#
# \[
# |106.3636 - 196.3636| = 90^\circ
# \]
#
# Lo que confirma el resultado.
#
# ---
#
# ### **Conclusión final**
#
# Aunque a las 3:15 las manecillas no forman un ángulo de 90°, entre las 3:00 y las 4:00 las manecillas forman un ángulo de 90°:
#
# - A las **3:00**.
# - Aproximadamente a las **3:32:44**.
#
# ---
#
# Si el problema se refería a que a las 3:15 se había visto un ángulo de 90° y luego queremos saber cuándo se repite, entonces las respuestas son:
#
# \[
# \boxed{
# \text{Sólo aproximadamente a las 3:32:44 minutos}
# }
# \]
#
# Pero como a las 3:15 el ángulo no es 90 grados, quizás el problema tiene algún error o está preguntando en general.
#
# ---
#
# **¿Quieres que te ayude a calcular exactamente en qué minutos las manecillas forman un ángulo de 90° en el intervalo dado?**

# %% [markdown]
# # ¡Felicidades!
#
# ¡Ese fue un pequeño y sencillo paso hacia la IA Agentic con tu nuevo entorno!
#
# La próxima vez que las cosas se pongan más interesantes...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">Ejercicio</h2>
# <span style="color:#ff7800;">Ahora, prueba esta aplicación comercial:<br/>
# Primero, pide al LLM que elija un área de negocio que valga la pena explorar para una oportunidad de IA con Agentic.<br/>
# Después, pide al LLM que presente un problema en esa industria, algo desafiante que pueda ser propicio para una solución con Agentic.<br/>
# Finalmente, pide a la tercera convocatoria del LLM que proponga la solución de IA con Agentic. </span>
# </td>
# </tr>
# </table>

# %%
# Priemro creamos el mensaje

messages = [{"role": "user", "content": "Genera una idea de negocio innovadora en el sector de las telecomunicaciones."}]

# Hacemos la primera llamada:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)
# Luego leemos la idea de negocio:

business_idea = response.choices[0].message.content

print("Idea de negocio:", business_idea)

# Y repetimos!
# Out:
# Idea de negocio: Claro, aquí tienes una idea innovadora para el sector de las telecomunicaciones:
#
# **Plataforma de Conectividad Híbrida Inteligente para Zonas Rurales y Desconectadas**
#
# **Descripción:**
# Desarrollar una plataforma que integre múltiples tecnologías de conectividad (satélite, 4G/5G, redes Wi-Fi mesh y tecnologías emergentes de IoT) para ofrecer acceso a internet fiable y de alta calidad en zonas rurales, comunidades aisladas y áreas con infraestructura limitada.
#
# **Cómo funciona:**
# - **Conectividad combinada:** La plataforma utiliza inteligencia artificial para seleccionar dinámicamente la mejor fuente de conexión disponible en función de la ubicación, la demanda y las condiciones ambientales.
# - **Red mesh local:** Implementación de redes Wi-Fi mesh gestionadas desde nodos locales con capacidad de gestionar el tráfico de datos y priorizar aplicaciones críticas (educación, salud, emergencias).
# - **Dispositivos IoT adaptativos:** Integrar dispositivos IoT que monitoricen el estado de la red, la calidad del servicio y las necesidades de los usuarios para optimizar la gestión.
# - **Modelo de negocio inclusivo:** Ofrecer servicios bajo un modelo de suscripción flexible o mediante alianzas con gobiernos y ONGs para subvencionar el acceso en comunidades vulnerables.
#
# **Valor diferencial:**
# - Solución adaptativa que maximiza la eficiencia de recursos tecnológicos disponibles.
# - Mejora el acceso digital para sectores marginados, fomentando la inclusión social y económica.
# - Escalabilidad y replicabilidad en diferentes regiones con desafíos similares.
# - Posibilidad de integrarse con plataformas educativas, de salud y de administración pública.
#
# ¿Quieres que te ayude a desarrollar un plan de negocio o una estrategia de entrada al mercado para esta idea?

# %%
# Imprimo en formato Markdown la respuesta
display(Markdown(business_idea))
# Out:
# Claro, aquí tienes una idea innovadora para el sector de las telecomunicaciones:
#
# **Plataforma de Conectividad Híbrida Inteligente para Zonas Rurales y Desconectadas**
#
# **Descripción:**
# Desarrollar una plataforma que integre múltiples tecnologías de conectividad (satélite, 4G/5G, redes Wi-Fi mesh y tecnologías emergentes de IoT) para ofrecer acceso a internet fiable y de alta calidad en zonas rurales, comunidades aisladas y áreas con infraestructura limitada.
#
# **Cómo funciona:**
# - **Conectividad combinada:** La plataforma utiliza inteligencia artificial para seleccionar dinámicamente la mejor fuente de conexión disponible en función de la ubicación, la demanda y las condiciones ambientales.
# - **Red mesh local:** Implementación de redes Wi-Fi mesh gestionadas desde nodos locales con capacidad de gestionar el tráfico de datos y priorizar aplicaciones críticas (educación, salud, emergencias).
# - **Dispositivos IoT adaptativos:** Integrar dispositivos IoT que monitoricen el estado de la red, la calidad del servicio y las necesidades de los usuarios para optimizar la gestión.
# - **Modelo de negocio inclusivo:** Ofrecer servicios bajo un modelo de suscripción flexible o mediante alianzas con gobiernos y ONGs para subvencionar el acceso en comunidades vulnerables.
#
# **Valor diferencial:**
# - Solución adaptativa que maximiza la eficiencia de recursos tecnológicos disponibles.
# - Mejora el acceso digital para sectores marginados, fomentando la inclusión social y económica.
# - Escalabilidad y replicabilidad en diferentes regiones con desafíos similares.
# - Posibilidad de integrarse con plataformas educativas, de salud y de administración pública.
#
# ¿Quieres que te ayude a desarrollar un plan de negocio o una estrategia de entrada al mercado para esta idea?

# %%
#Obtenemos una respuesa al desafio
messages = [{"role": "user", "content": business_idea}]

answer = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
).choices[0].message.content

# %%
#Imprimo la respuesta en formato Markdown

display(Markdown(answer))
# Out:
# ¡Me parece una idea excelente y con un gran potencial de impacto social! Puedo ayudarte con gusto a desarrollar tanto un plan de negocio como una estrategia de entrada al mercado para esta Plataforma de Conectividad Híbrida Inteligente.
#
# Para comenzar, aquí te dejo un esquema básico para el plan de negocio, y me dices si quieres que profundicemos en alguna sección específica:
#
# ---
#
# ### Plan de Negocio para Plataforma de Conectividad Híbrida Inteligente
#
# **1. Resumen Ejecutivo**
# - Visión y misión
# - Descripción del producto
# - Mercado objetivo
# - Propuesta de valor
#
# **2. Análisis de Mercado**
# - Tamaño del mercado y potencial de crecimiento (zonas rurales y desconectadas)
# - Análisis de competidores y soluciones existentes
# - Necesidades y comportamientos del cliente
#
# **3. Propuesta de Valor y Producto**
# - Características principales de la plataforma
# - Tecnología envolvente (IA, redes mesh, IoT)
# - Beneficios clave para usuarios y stakeholders
#
# **4. Modelo de Negocio**
# - Fuentes de ingresos (suscripciones, alianzas públicas/privadas, subvenciones)
# - Estructura de costos (desarrollo, infraestructura, mantenimiento)
# - Estrategia de precios flexible para diferentes segmentos
#
# **5. Estrategia de Entrada al Mercado**
# - Pilotos en comunidades específicas para validar tecnología y modelo
# - Alianzas con gobiernos locales, ONGs, y empresas telecom para despliegue y financiamiento
# - Campañas de sensibilización y educación digital
#
# **6. Plan Operativo**
# - Desarrollo tecnológico y equipos necesarios
# - Logística para instalación y mantenimiento en zonas rurales
# - Soporte técnico y atención al cliente
#
# **7. Análisis Financiero**
# - Proyecciones de ingresos y gastos para 3-5 años
# - Punto de equilibrio
# - Fuentes de financiación inicial y crecimiento (inversionistas, subvenciones, crowdfunding)
#
# **8. Impacto Social y Sostenibilidad**
# - Métricas para medir la inclusión digital y mejoras en educación/salud
# - Estrategias para asegurar sostenibilidad económica y social a largo plazo
#
# ---
#
# Si quieres, también puedo ayudarte a armar presentaciones para inversores, documentos para aliados gubernamentales o guiones para pitches.
#
# ¿Quieres empezar por alguna sección en particular o prefieres que te ayude a estructurar la estrategia de entrada al mercado?
